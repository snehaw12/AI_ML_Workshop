# %%
#dataset ; birthwt.csv
#location:https://mitu.co.in/dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('birthwt_a.csv')

# %%
df.head()
# Out:
#    low  age  lwt  race  smoke  ptl  ht  ui  ftv   bwt
# 0    0   19  182     2      0    0   0   1    0  2523
# 1    0   33  155     3      0    0   0   0    3  2551
# 2    0   20  105     1      1    0   0   0    1  2557
# 3    0   21  108     1      1    0   0   1    2  2594
# 4    0   18  107     1      1    0   0   1    0  2600

# %%
df.shape
# Out:
# (189, 10)

# %%
x = df['age']
y = df['bwt']

# %%
plt.scatter(x,y)

# %%
df.corrwith(df['age'])
# Out:
# low     -0.118939
# age      1.000000
# lwt      0.180073
# race    -0.172818
# smoke   -0.044346
# ptl      0.071606
# ht      -0.015837
# ui      -0.075156
# ftv      0.215394
# bwt      0.090318
# dtype: float64

# %%
import numpy as np
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.09031781],
#        [0.09031781, 1.        ]])

# %%
import seaborn as sns
sns.regplot(x='age', y='bwt',data = df)
# Out:
# <Axes: xlabel='age', ylabel='bwt'>

# %%
sns.lmplot(x='age', y='bwt', data = df)

# %%
import scipy.stats as st
st.linregress(x,y)
# Out:
# LinregressResult(slope=12.429712027714631, intercept=2655.7444697051715, rvalue=0.09031781366853263, pvalue=0.2164752418551902, stderr=10.022781130420993, intercept_stderr=238.8570916980437)

# %%
st.linregress(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 st.linregress(x,y)
#
# AttributeError: module 'statistics' has no attribute 'linregress'
