# %%
#plot the normal distribution for class test result of a
#particular subject identify the skewness and kurtosis

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('student.csv')

# %%
df['marks']
# Out:
# 0    56.77
# 1    59.77
# 2    76.88
# 3    69.66
# 4    63.28
# 5    49.55
# 6    65.34
# 7    68.33
# 8    56.75
# 9    78.66
# Name: marks, dtype: float64

# %%
SNS.KDPLOT(DF['MARKS'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 SNS.KDPLOT(DF['MARKS'])
#
# NameError: name 'SNS' is not defined

# %%
sns.kdeplot(df['marks'])
# Out:
# <Axes: xlabel='marks', ylabel='Density'>

# %%
marks = [56,61,82,65,62,60,58,65,61]
sns.kdeplot(marks)
# Out:
# <Axes: ylabel='Density'>

# %% [raw]
# marks =
# sns.kdeplot(marks)

# %%
marks= [86,85,65,76,89,75,54,75,85,89,90]
sns.kdeplot(marks)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# marks = [86,85,65,76,89,75,54,75,85,89,90]
# sns.kdeplot(marks)

# %%
sns.kdeplot(marks1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.kdeplot(marks1)
#
# NameError: name 'marks1' is not defined

# %%
marks = [65,64,67,66,65,63,68,67,65,90,45]
sns.kdeplot(marks)
# Out:
# <Axes: ylabel='Density'>
